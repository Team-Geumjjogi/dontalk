# %% [markdown]
# # 실험 제목
# - 담당:
# - 날짜:
# - 목적: 무엇이 궁금한가?
#
# > 끝나면 결과를 `experiments/LOG.md`에 한 줄 남기기

# %%
import json
import pandas as pd

# 레포 최상위 폴더에서 노트북을 연다고 가정 (data/ 경로 기준)
df = pd.read_json('data/processed/qa_flat.jsonl', lines=True)
df.head()

# %% [markdown]
# ## 관찰 / 메모
