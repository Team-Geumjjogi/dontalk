# %% [markdown]
# ## 데이터 읽기

# %% [markdown]
# 원천 데이터 구조

# %% [markdown]
# ```json
# {
#     "source": {
#         "source_institution": "하나증권",
#         "source_id": "21-1_sec_07_000015",
#         "source_date": "202504",
#         "client_gender": "남",
#         "client_age": "60~69세",
#         "consulting_client": "기존고객",
#         "consulting_client_type": "개인사업자",
#         "source_length": 1079,
#         "consulting_content": "TX 고객님, 현재 ★★ ▲▲▲와 관련하여 상담 중입니다. 무엇을 도와드릴까요?\nTX 비대면 계좌 개설 후 타사로 출고하려는 상황을 파악했습니다. 절차를 차근차근 안내드리겠습니다.\nRX 지금 ★★에서 타사 대체 출고를 진행하려고 하는데요.\nRX 여기 보니 제가 어제 신규 계좌를 개설했어요.\nRX 그런데 이 계좌로 이체를 시도했더니 상대 계좌번호와 명의가 일치하지 않는다고 나와요.\nRX 그래서 확인을 좀 해보고 싶어요.\nTX 확인을 위해 몇 가지 정보를 여쭤보겠습니다. 고객님의 성함과 계좌번호를 알려주시면 진행하겠습니다.\nRX ◆◆◆ 네, 확인해 주세요. 빠른 처리 부탁드립니다.\nRX ▲▲▲ 네, 맞습니다. 추가 확인 필요하시면 알려 주세요.\nTX 고객님의 계좌를 조회해 보니 현재 정상 상태로 확인됩니다. 추가 확인이 필요하시면 알려 주세요.\nTX 다만, 동일 명의가 아니라고 표시되는 경우는 상대 계좌와 명의가 일치하지 않을 때 발생합니다. 확인 절차를 안내드리겠습니다.\nRX 그럼 여쭤볼게요, 비대면으로 계좌를 개설했는데.\nRX 여기 지점명을 어떻게 입력해야 하는지요.\nTX 비대면 계좌 개설 시 지점명은 실제 영업점명을 입력하셔야 합니다. 현재 화면에 표시된 ‘★★’은 본사 코드이므로, 가까운 지점명을 입력해 주세요.\nRX 아니에요, 현재 ★★ 화면에 상대 지점명을 적어야 하는데, 정확히 무엇을 적어야 할지 궁금해요.\nTX 상대 지점명은 이체를 진행하려는 은행 혹은 지점의 정식 명칭을 입력하셔야 합니다. 예를 들어 ‘서울지점’이나 ‘부산본점’과 같이 표기해 주세요.\nRX 그 다음 상대 계좌명은 어떻게 적어야 하는지요.\nTX 계좌명은 수취인 명의와 정확히 일치해야 합니다. 고객님의 경우 상대 계좌명의가 ‘홍길동’이라면 그대로 입력해 주시면 됩니다.\nRX 계좌번호는 맞고, 상대 계좌번호도 확인했어요.\nRX 이 모든 절차가 비대면 온라인으로 진행되는 건가요.\nTX 네, 현재 비대면 온라인으로 모든 입력 및 확인이 가능합니다. 단, 보안 인증 절차가 추가로 요구될 수 있습니다.\nRX 네, 알겠습니다. 추가 안내 부탁드려요.\nTX 이제 추가로 몇 가지 확인이 필요합니다. 먼저, 이체 금액과 수수료에 대해 안내드리겠습니다. 타사로 출고할 경우 기본 수수료는 0.15%이며, 최소 1,000원입니다.\nRX 그럼 이체 한도는 어떻게 되나요? 현재 한도에 걸릴까 걱정돼요.\nTX 이체 한도는 하루 5천만원까지 가능합니다. 한도가 초과될 경우 추가 인증을 통해 한도 상향이 가능합니다.\nRX 해외 주식도 이 앱에서 바로 거래할 수 있나요?\nTX 해외 주식 거래는 별도 약정이 필요하고, 실시간 시세 이용료와 환전 수수료가 발생합니다. 필요하시면 절차를 안내해 드리겠습니다.\nRX 비밀번호와 인증번호 입력을 도와줄 수 있나요?\nTX 계좌 확인을 위해 비밀번호와 OTP(일회용 비밀번호)를 입력해 주시기 바랍니다. 입력이 완료되면 바로 진행됩니다.\nTX 추가로 궁금하신 점이 있으면 언제든 알려 주세요. 필요한 서류나 절차도 상세히 안내드리겠습니다."
#     },
#     "consulting": {
#         "consulting_category": "증권",
#         "consulting_topic": "증권계좌조회",
#         "consulting_summary": "고객은 비대면 계좌 개설 후 타사로 출고하려다 상대 계좌명과 지점명 입력 방법 및 명의 불일치 오류를 문의하였고, 상담사는 정상 계좌 확인 후 입력 방법과 수수료, 한도, 보안 절차를 안내하였다."
#     },
#     "qa_data": [
#         {
#             "qa_id": "21-1_sec_07_000015_001",
#             "task_category": "핵심 금융 용어",
#             "consulting_situation": "일반문의",
#             "qa_topic": "증권계좌조회",
#             "consulting_purpose": "비대면 출고 안내",
#             "core_financial_terms": "계좌이체",
#             "input_length": 230,
#             "instruction": "비대면 계좌 개설 후 타사 출고 절차와 이체 한도를 안내하시오.",
#             "input": {
#                 "question": "제가 어제 신규 계좌를 개설했어요. 계좌로 이체를 시도했더니 상대 계좌번호와 명의가 일치하지 않는다고 나와요. 비대면으로 계좌를 개설했는데 지점명을 어떻게 입력해야 하는지요.",
#                 "answer": "고객님의 계좌를 조회해 보니 현재 정상 상태로 확인됩니다. 다만, 동일 명의가 아니라고 표시되는 경우는 상대 계좌와 명의가 일치하지 않을 때 발생합니다. 비대면 계좌 개설 시 지점명은 실제 영업점명을 입력하셔야 합니다. 현재 화면에 표시된 ‘★★’은 본사 코드이므로, 가까운 지점명을 입력해 주세요.",
#                 "follow_up_question": "이체 한도는 어떻게 되나요? 현재 한도에 걸릴까 걱정돼요. "
#             },
#             "output": "비대면 계좌 개설 시에는 실제 영업점명을 정확히 입력해 주시고, 화면에 표시된 본사 코드는 제외해 가까운 지점을 선택해 주시기 바랍니다. 이체 시에는 상대 은행과 지점의 정식 명칭을 입력하고 수취인 명의와 계좌명이 일치하도록 작성해 주시며, 모든 절차는 온라인으로 진행되고 추가 보안 인증이 요구될 수 있습니다. 하루 이체 한도는 5천만 원이며, 초과 시 추가 인증을 통해 한도 상향이 가능합니다."
#         }
#     ]
# }

# %%
# 라벨링 데이터_Training Data

from pathlib import Path
import json
import pandas as pd

# current = Path.cwd()

# while current != current.parent and not (current / "data").exists():
#     current = current.parent

# root = current / "data" / "raw" / "Training"

root = Path("../../data/raw/Training")
rows = []
errors = []

for path in root.rglob("*.json"):
    try:
        with path.open("r", encoding="utf-8") as f:
            item = json.load(f)

        # 출처 정보도 보존하면 나중에 추적하기 좋음
        item["_source_file"] = str(path)

        rows.append(item)

    except Exception as e:
        errors.append((str(path), str(e)))

df = pd.json_normalize(rows)

print(df.shape)
print(f"읽기 실패: {len(errors)}개")

# %%
# 라벨링 데이터_Validation Data

from pathlib import Path
import json
import pandas as pd

root = Path("../../data/raw/Validation")
rows = []
errors = []

for path in root.rglob("*.json"):
    try:
        with path.open("r", encoding="utf-8") as f:
            item = json.load(f)

        # 출처 정보도 보존하면 나중에 추적하기 좋음
        item["_source_file"] = str(path)

        rows.append(item)

    except Exception as e:
        errors.append((str(path), str(e)))

df = pd.json_normalize(rows)

print(df.shape)
print(f"읽기 실패: {len(errors)}개")

# %%
df.head(1).qa_data[0]

# %%
# extract 'qa_topic'

df["qa_data"].explode().apply(
    lambda x: x.get("qa_topic") if isinstance(x, dict) else None
).value_counts()

# %%
#consulting_purpose
a= df["qa_data"].explode().apply(
    lambda x: x.get("consulting_purpose") if isinstance(x, dict) else None
).unique()

print(len(a))

#core_financial_terms
b= df["qa_data"].explode().apply(
    lambda x: x.get("core_financial_terms") if isinstance(x, dict) else None
).value_counts()
print(len(b))
print(b)

# %% [markdown]
# ## 데이터 DF에 통합

# %%
# json 데이터 하나로 모아 df에 저장
from pathlib import Path
import json
import pandas as pd

root = Path("../../data/raw/Training")

category_map = {
    "은행": {
        "01": "거래내역/잔액조회",
        "02": "중계요청/착오송금",
        "03": "자동이체조회",
        "04": "만기,연장/해지,수신",
        "05": "금융거래한도/비대면한도계좌",
        "06": "이자/연체금액",
        "07": "부수거래금리감면",
        "08": "대출문의(만기/연장/조회등)",
        "09": "환전문의",
    },
    "보험": {
        "01": "자동차보험상담",
        "02": "자동차사고접수",
        "03": "계약내용변경/해지",
        "04": "기타계약관련문의",
        "05": "보험금청구",
    },
    "증권": {
        "01": "HTS/MTS",
        "02": "계좌관리",
        "03": "신용거래/담보대출",
        "04": "자금이체/계좌제한",
        "05": "절세형금융상품",
        "06": "주식주문",
        "07": "증권계좌조회",
        "08": "해외주문",
    }
}

domain_map = {
    "bk": "은행",
    "ins": "보험",
    "sec": "증권",
}

# json 내부 데이터 > df 형태로 변환
def flatten_json(data):
    """JSON 내부의 중첩된 dictionary를 펼쳐서
    DataFrame 컬럼 형태로 변환"""
    result = {}

    # --------------------------------
    # source
    # --------------------------------
    # 예: source.source_institution -> source_source_institution
    if isinstance(data.get("source"), dict):
        for key, value in data["source"].items():
            result[f"source_{key}"] = value

    # --------------------------------
    # consulting
    # --------------------------------
    # 예: consulting.xxx -> consulting_xxx
    if isinstance(data.get("consulting"), dict):
        for key, value in data["consulting"].items():
            result[f"consulting_{key}"] = value

    # --------------------------------
    # qa_data
    # --------------------------------
    # qa_data는 리스트이며 첫 번째 항목 사용
    if isinstance(data.get("qa_data"), list) and data["qa_data"]:
        qa = data["qa_data"][0]

        if isinstance(qa, dict):
            for key, value in qa.items():

                # qa_data.input.xxx -> qa_data_input_xxx
                if key == "input" and isinstance(value, dict):
                    for input_key, input_value in value.items():
                        result[f"qa_data_input_{input_key}"] = input_value
                else:
                    result[f"qa_data_{key}"] = value

    return result


# 전체 json 파일 수집
all_data = []
errors = []



# Training 하위 모든 JSON 탐색
for json_path in root.rglob("*.json"):
    try:
        filename = json_path.name
        filename_without_ext = json_path.stem

        # 예: 21-1_ins_01_019557_001.json
        parts = filename_without_ext.split("_")

        if len(parts) < 3:
            raise ValueError(f"예상한 파일명 형식이 아닙니다: {filename}")

        data_field_code = parts[0]  # 예: 21-1
        domain_code = parts[1]      # 예: ins
        middle_code = parts[2]      # 예: 01

        domain_name = domain_map.get(
            domain_code,
            f"Unknown({domain_code})"
        )

        middle_name = category_map.get(
            domain_name, {}
        ).get(
            middle_code,
            f"Unknown({middle_code})"
        )

        with json_path.open("r", encoding="utf-8") as f:
            json_data = json.load(f)

        json_flattened = flatten_json(json_data)

        row = {
            "파일명": filename,
            "데이터분야별코드": data_field_code,
            "분류코드": domain_code,  # 위 코드와 컬럼명 통일
            "도메인명": domain_name,
            "중분류코드": middle_code,
            "중분류명": middle_name,
            "파일경로": str(json_path),
        }

        row.update(json_flattened)
        all_data.append(row)

    except Exception as e:
        errors.append({
            "파일경로": str(json_path),
            "오류": str(e)
        })

df = pd.DataFrame(all_data)

print(f"DataFrame 크기: {df.shape}")

df

# %%
# Excel에서 열어 확인하기 위한 CSV 파일
# CSV용 복사본 생성: 원본 df는 변경하지 않음
df_csv = df.copy()

# Pandas 경고 없이 문자열 컬럼 선택
text_columns = df_csv.select_dtypes(
    include=["object", "string"]
).columns

# 실제 줄바꿈 및 비정상 줄 구분 문자를 문자 "\\n"으로 변환
def normalize_line_breaks(value):
    if not isinstance(value, str):
        return value

    return (
        value.replace("\r\n", "\\n")  # Windows 줄바꿈
             .replace("\n", "\\n")    # Unix 줄바꿈
             .replace("\r", "\\n")    # 옛 Mac 줄바꿈
             .replace("\u0085", "\\n")  # NEL
             .replace("\u2028", "\\n")  # LS
             .replace("\u2029", "\\n")  # PS
    )

for col in text_columns:
    df_csv[col] = df_csv[col].map(normalize_line_breaks)

# Excel 확인용 CSV 저장
df_csv.to_csv(
    "training_raw.csv",
    index=False,
    encoding="utf-8-sig",
    lineterminator="\n"
)

print(f"DataFrame 행 수: {len(df_csv):,}")

# %%
# Parquet 파일 - 나중에 다시 불러오기 용이
# uv add pyarrow
df.to_parquet(
    "training_raw.parquet",
    index=False
)
df_parquet = pd.read_parquet("training_raw.parquet")

print(df_parquet.shape)   # 행, 열 개수
display(df_parquet.head())  # 앞 5개 행 보기

# 나중에 다시 불러올 때 -> df = pd.read_parquet("training_raw.parquet")

# %%
# 데이터 정제 (마스킹 기호, 식별자 등 직관화)
from pathlib import Path
import re
import pandas as pd

# --------------------------------------------------
# 파일 경로
# --------------------------------------------------
input_parquet = Path("training_raw.parquet")

output_csv = Path("training_processed.csv")
output_parquet = Path("training_processed.parquet")

# 결측치·마스킹 표기 규칙
MISSING_VALUE = "알수없음"

# 필요하면 여기에 데이터에 등장하는 마스킹 기호를 추가하세요.
MASK_PATTERN = re.compile(r"[★▲◆●■□◇○△▼]+")

# --------------------------------------------------
# 텍스트 정제 함수
# --------------------------------------------------
def clean_text(value):
    """텍스트형 셀에만 적용하는 정제 함수"""

    if not isinstance(value, str):
        return value

    # 기존 CSV에서 줄바꿈을 문자 '\\n'으로 저장한 경우 복원
    # 이후 최종 CSV 저장 시 실제 줄바꿈은 다시 제거됨
    text = value.replace("\\n", "\n")

    # LS, PS 등 비정상 줄 구분 문자 처리
    text = (
        text.replace("\u0085", "\n")
            .replace("\u2028", "\n")
            .replace("\u2029", "\n")
    )

    # 마스킹 기호를 OOO로 통일
    text = MASK_PATTERN.sub("OOO", text)

    # 발화자 태그 변환
    # 각 줄의 시작에 있는 TX / RX만 치환
    text = re.sub(
        r"(?m)^[ \t]*TX\s*[:：]?\s*",
        "상담사: ",
        text
    )
    text = re.sub(
        r"(?m)^[ \t]*RX\s*[:：]?\s*",
        "고객: ",
        text
    )

    # 연속된 문장부호 압축: ... → ., ,,, → ,
    text = re.sub(r"([.,?!])\1+", r"\1", text)

    # 문장 종결 기호 뒤 띄어쓰기 보정
    text = re.sub(r"([.?!])([^\s])", r"\1 \2", text)

    # 줄바꿈·탭·연속 공백을 한 칸으로 압축
    text = re.sub(r"\s+", " ", text).strip()

    return text

# --------------------------------------------------
# 결측치 처리
# --------------------------------------------------
def replace_blank_with_missing(value):
    """빈 문자열 또는 공백뿐인 문자열을 알수없음으로 변경"""

    if isinstance(value, str) and not value.strip():
        return MISSING_VALUE

    return value

# --------------------------------------------------
# 원본 읽기 및 정제
# --------------------------------------------------
df_raw = pd.read_parquet(input_parquet)

# 원본을 보존하기 위해 복사본에서 작업
df_processed = df_raw.copy()

# NaN, None 처리
df_processed = df_processed.fillna(MISSING_VALUE)

# 빈 문자열/공백만 있는 값 처리
df_processed = df_processed.map(replace_blank_with_missing)

# 문자열 컬럼에 텍스트 정제 적용
text_columns = df_processed.select_dtypes(
    include=["object", "string"]
).columns

for col in text_columns:
    df_processed[col] = df_processed[col].map(clean_text)

print(f"원본 행 수: {len(df_raw):,}")
print(f"정제 후 행 수: {len(df_processed):,}")

# --------------------------------------------------
# 정제 결과 저장
# --------------------------------------------------

# 분석·재사용용: 원래 타입을 최대한 유지
df_processed.to_parquet(
    output_parquet,
    index=False
)

# Excel 확인용: 한 데이터가 CSV 한 줄만 차지하도록 저장
df_processed.to_csv(
    output_csv,
    index=False,
    encoding="utf-8-sig",
    lineterminator="\n"
)

print(f"Parquet 저장 완료: {output_parquet}")
print(f"CSV 저장 완료: {output_csv}")

# %%
display(
    df_processed[
        [
            "source_consulting_content",
            "source_consulting_client_type",
            "qa_data_input_question",
            "qa_data_input_answer",
            "qa_data_output",
        ]
    ].head(10)
)
